# %% [markdown]
# Measuring the impact of selecting best mcv parameters on clustering.

# %%
import pandas as pd
import scanpy as sc
from sklearn.metrics import mean_squared_error
from scipy.sparse import issparse
from matplotlib import pyplot as plt

# %matplotlib inline

import numpy as np
from tqdm import tqdm

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from downstream import *
from sweep import *
from data import *

# %%
symsim = load_symsim(suffix = '2k')

denoised_symsim = mcv_sweep_recipe_pca(symsim, recipe_sqrt)
# Out:
# 100%|██████████| 18/18 [00:00<00:00, 82.14it/s]

# %%
cluster_denoised(denoised_symsim, 'pop')
# Out:
#   0%|          | 0/18 [00:00<?, ?it/s]
# There are 5 true clusters.
# 100%|██████████| 18/18 [00:54<00:00,  3.05s/it]

# %%
plot_scalars(denoised_symsim, ['mcv', 'ari', 'imputed_ari', 'ari_kmeans', 'n_clusters'])

# %%
plot_mcv_ari(denoised_symsim)

# %% [markdown]
# # Blood

# %%
blood = load_blood()

denoised_blood = mcv_sweep_recipe_pca(blood, recipe_seurat, max_pcs=100)
# Out:
# 100%|██████████| 32/32 [01:31<00:00,  2.85s/it]

# %%
cluster_denoised(denoised_blood, 'cell_type', adaptive=False, kmeans=True)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# There are 9 true clusters.
#  44%|████▍     | 14/32 [04:41<06:01, 20.11s/it]/Users/josh/anaconda3/envs/n2s/lib/python3.7/site-packages/umap/spectral.py:229: UserWarning: Embedding a total of 2 separate connected components using meta-embedding (experimental)
#   n_components
#  50%|█████     | 16/32 [05:29<05:50, 21.91s/it]/Users/josh/anaconda3/envs/n2s/lib/python3.7/site-packages/umap/spectral.py:229: UserWarning: Embedding a total of 2 separate connected components using meta-embedding (experimental)
#   n_components
#  62%|██████▎   | 20/32 [06:54<04:17, 21.43s/it]/Users/josh/anaconda3/envs/n2s/lib/python3.7/site-packages/umap/spectral.py:229: UserWarning: Embedding a total of 2 separate connected components using meta-embedding (experimental)
#   n_components
# ...

# %%
plot_scalars(denoised_blood, ['mcv', 'ari', 'imputed_ari', 'ari_kmeans', 'ari1', 'imputed_ari1', 'n_clusters'])

# %%
plot_mcv_ari(denoised_blood)

# %%
plot_mcv_ari(denoised_blood)

# %% [markdown]
# # Kidney

# %%
kidney = load_kidney()

# %%
highly_variable(kidney)
# Out:
# 2216 highly variable genes.

# %%
denoised_kidney = mcv_sweep_recipe_pca(kidney, recipe_sqrt, max_pcs=100)

# %%
cluster_denoised(denoised_kidney, 'cell_ontology_class', adaptive=False)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# There are 23 true clusters.
# /Users/josh/anaconda3/envs/n2s/lib/python3.7/site-packages/numba/compiler.py:602: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../anaconda3/envs/n2s/lib/python3.7/site-packages/umap/nndescent.py", line 47:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   self.func_ir.loc))
#
#   3%|▎         | 1/32 [00:30<15:58, 30.91s/it]/Users/josh/anaconda3/envs/n2s/lib/python3.7/site-packages/numba/compiler.py:602: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# ...

# %%
plot_scalars(denoised_kidney, ['mcv', 'ari', 'imputed_ari', 'ari_kmeans', 'n_clusters'])

# %%
def plot_mcv_ari(denoised):
    params = [adata.uns['denoiser_param'] for adata in denoised]
    mcv = [adata.uns['mcv'] for adata in denoised]
    ari = np.array([adata.uns['imputed_ari'] for adata in denoised])

    fig, ax1 = plt.subplots()

    color = 'tab:red'
    ax1.set_xlabel('PCs')
    ax1.set_ylabel('mcv', color=color)
    ax1.plot(params, mcv, color=color)
    ax1.tick_params(axis='y', labelcolor=color)

    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

    color = 'tab:blue'
    ax2.set_ylabel('1 - ari', color=color)  # we already handled the x-label with ax1
    ax2.plot(params, 1 - ari, color=color)
    ax2.tick_params(axis='y', labelcolor=color)

    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    plt.show()

# %%
plot_mcv_ari(denoised_kidney)

# %% [markdown]
# # Paul

# %%
paul = sc.datasets.paul15()
paul.raw = paul
# Out:
# WARNING: In Scanpy 0.*, this returned logarithmized data. Now it returns non-logarithmized data.
# ... storing 'paul15_clusters' as categorical
# Trying to set attribute `.uns` of view, making a copy.

# %%
paul.obs['paul15_clusters'].unique()
# Out:
# [7MEP, 15Mo, 3Ery, 4Ery, 2Ery, ..., 6Ery, 19Lymph, 12Baso, 18Eos, 11DC]
# Length: 19
# Categories (19, object): [7MEP, 15Mo, 3Ery, 4Ery, ..., 19Lymph, 12Baso, 18Eos, 11DC]

# %%
denoised_paul = mcv_sweep_recipe_pca(paul, recipe_sqrt, max_pcs=30)
# Out:
# 100%|██████████| 32/32 [00:03<00:00,  8.85it/s]

# %%
# cluster_denoised(denoised_paul, 'paul15_clusters', adaptive=False)
plot_scalars(denoised_paul, ['mcv', 'ari', 'imputed_ari', 'n_clusters'])

# %%
best_denoised = extract_best(denoised_paul)

# %%
sc.pl.umap(best_denoised, color=['leiden', ])
